# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button
import sunpy.io.fits
import matplotlib.pyplot as plt
from pathlib import Path
from matplotlib.gridspec import GridSpec
from matplotlib.ticker import MultipleLocator
# %matplotlib qt5

# %%
hdpairs = sunpy.io.fits.read('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091538_l1p_003_001_0160.fits')

# %%
len(hdpairs)
# Out:
# 1

# %%
data, header = hdpairs[0]

# %%
data.shape
# Out:
# (4, 1010, 440, 1)

# %%
header
# Out:
# FileHeader([('SIMPLE', True),
#             ('BITPIX', 32),
#             ('NAXIS', 4),
#             ('NAXIS1', 1),
#             ('NAXIS2', 440),
#             ('NAXIS3', 1010),
#             ('NAXIS4', 4),
#             ('SOLARNET', 1.0),
#             ('OBS_HDU', 1),
#             ('COMMENT',
#              '------------------------------------------------------------------------------------------Documentation & Contact Information-------------------This Fits-File is a level1 GRIS data file. All header values arecompliant to the SOLARNET recommedations Version 1.3a found at:http://sdc.uio.no/open/solarnet/Additional information for GRIS can be found at:https://doi.org/10.1002/asna.201211738Additional information for the GREGOR telescope can be found at:https://doi.org/10.1002/asna.201211725All data published and curated by the Leibniz Institute for SolarPhysics (KIS) (http://www.leibniz-kis.de) can be found at:http://sdc.leibniz-kis.de------------------------------------------------------------------------------------------------Observation Information---------------------------------------------------------------------------------------------------------------------------Temporal Information-----------------------------------------------------------------------------------------------------------------------Instrument and Processing Info----------------------------------------------------------------------------------------------------------------Detector Readout and Data Scaling-----------------------------------------------------------------------------------------------------------------Adaptive Optics and Derotator----------------------------------------------------------------------------------------------------------------------Projection and Pointing--------------------------------------------------------------------------------------------------------------------------Measurement Parameters------------------------------------------------------------------------------------------------------------------------------File Integrity-------------------------------------------------------------------------------------------------------------------------Continuum Correction Parameters----------------------------------------------------------------------------------------------------------------------------Provenance-------------------------------'),
#             ('FILENAME', 'gris_20201120_091538_l1p_003_001_0160.fits'),
#             ('EXTNAME', '20201120_003_001_0160'),
#             ('POINT_ID', '20201120_003'),
#             ('OBSERVER', 'Juan Carlos Trelles'),
#             ('OBS_TRGT', ''),
#             ('IOBS', 3),
#             ('NMAPS', 1),
#             ('IMAP', 1),
#             ('NSTEPS', 200),
#             ('ISTEP', 160),
#             ('DATE', '2021-12-03'),
#             ('DATE-OBS', '2020-11-20T09:15:38.066000'),
#             ('DATE-BEG', '2020-11-20T09:15:38.066000'),
#             ('LEVEL', 1.0),
#             ('CREATOR', 'gris_metadata_translator'),
#             ('ORIGIN', 'KIS'),
#             ('OBSRVTRY', 'Teide Observatory'),
#             ('TELESCOP', 'GREGOR'),
#             ('INSTRUME', 'GRIS'),
#             ('GRATING', 'GRIS'),
#             ('CAMERA', 'IR1024'),
#             ('OBSGEO-X', 5390228.444165787),
#             ('OBSGEO-Y', -1597755.873164848),
#             ('OBSGEO-Z', 3007127.73645809),
#             ('AWAVLNTH', 15650.0),
#             ('AWAVMAX', 15681.175),
#             ('AWAVMIN', 15640.899),
#             ('WAVEUNIT', -10),
#             ('OBS_MODE', 'single map pol'),
#             ('IMGSYS', 'SLIT'),
#             ('BTYPE', 'phot.flux'),
#             ('BUNIT', 'phot.flux'),
#             ('XPOSURE', 0.3),
#             ('EXPTIME', 0.3),
#             ('TEXPOSUR', 0.03),
#             ('NSUMEXP', 10),
#             ('AOSYSTEM', 'GAOS'),
#             ('AO_LOCK', None),
#             ('AO_NMODE', 0),
#             ('ATMOS_R0', 0.0),
#             ('ROTANGLE', -7.11876),
#             ('ROTCODE', -1),
#             ('ROTTRACK', None),
#             ('WCSNAME', 'Helioprojective Cartesian'),
#             ('CTYPE1', 'HPLN-TAN'),
#             ('CUNIT1', 'arcsec'),
#             ('CRPIX1', 1),
#             ('CRVAL1', -90.7),
#             ('CDELT1', -0.135),
#             ('CSYER1', 38.143944),
#             ('CTYPE2', 'HPLT-TAN'),
#             ('CUNIT2', 'arcsec'),
#             ('CRPIX2', 1),
#             ('CRVAL2', 76.4),
#             ('CDELT2', -0.135),
#             ('CSYER2', 38.143944),
#             ('CTYPE3', 'WAVE'),
#             ('CUNIT3', 'Angstrom'),
#             ('CRPIX3', 1),
#             ('CRVAL3', 15640.899),
#             ('CDELT3', 0.039917),
#             ('CSYER3', 0.039917),
#             ('CTYPE4', 'STOKES'),
#             ('CUNIT4', ''),
#             ('CRPIX4', 1),
#             ('CRVAL4', 1),
#             ('CDELT4', 1),
#             ('CSYER4', 0),
#             ('PC1_1', 0.0),
#             ('PC1_2', -1.0),
#             ('PC2_1', 1.0),
#             ('PC2_2', 0.0),
#             ('AZIMUT', None),
#             ('ELEV_ANG', None),
#             ('SLITORIE', None),
#             ('SLITPOSX', -61.0675),
#             ('SLITPOSY', 76.4),
#             ('RSUN_ARC', -1.0),
#             ('RSUN_REF', 695508000.0),
#             ('HGLT_OBS', None),
#             ('HGLN_OBS', 0.0),
#             ('DSUN_OBS', 147483493980.8359),
#             ('SOLAR_L0', None),
#             ('SOLAR_P0', None),
#             ('GRATANGL', 0.0),
#             ('SLIT_WID', 70.0),
#             ('STEPSIZE', 0.135),
#             ('STEPANGL', 0.0),
#             ('SLITCNTR', 'scancntr'),
#             ('CHECKSUM', 'ihnWlhmVihmVihmV'),
#             ('DATASUM', '2032622606'),
#             ('FF1WLOFF', 15640.907),
#             ('FF1WLDSP', 0.039907),
#             ('FF1FWHMA', 0.106316003435),
#             ('FF1FWHMP', 2.66411516938),
#             ('FF1STRAY', 0.107036003686),
#             ('FF1NPOLY', 28.0),
#             ('FF1PAR00', -0.0245654529024),
#             ('FF1PAR01', -0.00370299386975),
#             ('FF1PAR02', -0.000959596213988),
#             ('FF1PAR03', 0.000171534988198),
#             ('FF1PAR04', -2.41963246879e-05),
#             ('FF1PAR05', -3.14153230363e-06),
#             ('FF1PAR06', 1.51035297113e-06),
#             ('FF1PAR07', -3.85554290716e-08),
#             ('FF1PAR08', -2.33592284821e-08),
#             ('FF1PAR09', 1.48037214865e-09),
#             ('FF1PAR10', 1.52062670615e-10),
#             ('FF1PAR11', -1.4925169553e-11),
#             ('KEYCOMMENTS',
#              {'SIMPLE': 'conforms to FITS standard',
#               'BITPIX': 'array data type',
#               'NAXIS': 'number of array dimensions',
#               'NAXIS1': 'Length of data axis 1',
#               'NAXIS2': 'Length of data axis 2',
#               'NAXIS3': 'Length of data axis 3',
#               'NAXIS4': 'Length of data axis 4',
#               'SOLARNET': 'Fully SOLARNET-compliant',
#               'OBS_HDU': 'This HDU contains observational data',
#               'FILENAME': 'Name of file',
#               'EXTNAME': 'Unique HDU name',
#               'POINT_ID': 'Unique (re-)pointing ID',
#               'OBSERVER': 'Name of observer',
#               'OBS_TRGT': 'Observation Target',
#               'IOBS': 'Observation ID (unique within day)',
#               'NMAPS': 'Number of maps within observation',
#               'IMAP': 'Map ID (unique within observation)',
#               'NSTEPS': 'Number of steps per map',
#               'ISTEP': 'Slit position ID (unique within map)',
#               'DATE': '[UTC] Date of FITS file creation',
#               'DATE-OBS': '[UTC] Beginning of data acquisition',
#               'DATE-BEG': '[UTC] Beginning of data acquisition',
#               'LEVEL': 'Data level of fits file',
#               'CREATOR': 'Software that produced this file',
#               'ORIGIN': 'Location where FITS file has been created',
#               'OBSRVTRY': 'Name of observatory',
#               'TELESCOP': 'Name of telescope',
#               'INSTRUME': 'Name of instrument',
#               'GRATING': 'Name of grating used',
#               'CAMERA': 'Name of camera',
#               'OBSGEO-X': '[m] X coordinate of Cartesian triplet',
#               'OBSGEO-Y': '[m] Y coordinate of Cartesian triplet',
#               'OBSGEO-Z': '[m] Z coordinate of Cartesian triplet',
#               'AWAVLNTH': '[Angstrom] Characteristic wavelength',
#               'AWAVMAX': '[Angstrom] Max wavelength covered by filter',
#               'AWAVMIN': '[Angstrom] Min wavelength covered by filter',
#               'WAVEUNIT': 'File wide wavelength unit: 10^(WAVEUNIT)m',
#               'OBS_MODE': 'Mode of observation',
#               'IMGSYS': 'Imaging System (slit or ifu)',
#               'BTYPE': 'What the data array represents',
#               'BUNIT': 'Unit for data array',
#               'XPOSURE': '[s] Accumulated exposure time',
#               'EXPTIME': '[s] Accumulated exposure time',
#               'TEXPOSUR': '[s] Single-exposure time',
#               'NSUMEXP': 'Number of summed exposures',
#               'AOSYSTEM': 'Adaptive optic system',
#               'AO_LOCK': 'Adaptive optics status (0.0=no lock, 1.0=lock)',
#               'AO_NMODE': 'Number of corrected modes',
#               'ATMOS_R0': '[m] Atmospheric coherence length r0',
#               'ROTANGLE': '[degrees] rotator angle',
#               'ROTCODE': 'Derotator status (0:in, 1:out,-1:not installed)',
#               'ROTTRACK': 'Derotator status (2:stop 3:transient 4:locked)',
#               'WCSNAME': 'nan',
#               'CTYPE1': 'Type of coordinates along axis 1',
#               'CUNIT1': 'Units along axis 1',
#               'CRPIX1': 'Reference pixel',
#               'CRVAL1': 'Value at reference pixel on axis 1',
#               'CDELT1': 'Sampling along axis 1',
#               'CSYER1': 'Systematic Error along axis 1',
#               'CTYPE2': 'Type of coordinates along axis 2',
#               'CUNIT2': 'Units along axis 2',
#               'CRPIX2': 'Reference pixel',
#               'CRVAL2': 'Value at reference pixel on axis 2',
#               'CDELT2': 'Sampling along axis 2',
#               'CSYER2': 'Systematic Error along axis 2',
#               'CTYPE3': 'Type of coordinates along axis 3',
#               'CUNIT3': 'Units along axis 3',
#               'CRPIX3': 'Reference pixel',
#               'CRVAL3': 'Value at reference pixel on axis 3',
#               'CDELT3': 'Sampling along axis 3',
#               'CSYER3': 'Systematic Error along axis 3',
#               'CTYPE4': 'Type of coordinates along axis 4',
#               'CUNIT4': 'Units along axis 4',
#               'CRPIX4': 'Reference pixel',
#               'CRVAL4': 'Value at reference pixel on axis 4',
#               'CDELT4': 'Sampling along axis 4',
#               'CSYER4': 'Systematic Error along axis 4',
#               'PC1_1': 'Value of Rotation Matrix',
#               'PC1_2': 'Value of Rotation Matrix',
#               'PC2_1': 'Value of Rotation Matrix',
#               'PC2_2': 'Value of Rotation Matrix',
#               'AZIMUT': '[degrees] Sun center azimut',
#               'ELEV_ANG': '[degrees] Sun center elevation',
#               'SLITORIE': '[degrees] Slit orientation',
#               'SLITPOSX': '[arcsec] angle from disk center in HPC',
#               'SLITPOSY': '[arcsec] angle from disk center in HPC',
#               'RSUN_ARC': '[arcsec] Apparent solar radius',
#               'RSUN_REF': '[meters] Reference value for solar radius',
#               'HGLT_OBS': '[degrees] B0 angle',
#               'HGLN_OBS': '[degrees] Heliographic Longitude of observer',
#               'DSUN_OBS': '[meters] Distance from Instrument to Sun center',
#               'SOLAR_L0': '[degrees] L0 angle',
#               'SOLAR_P0': '[degrees] angle btwn celestial and solar north',
#               'GRATANGL': '[degrees] grating angle',
#               'SLIT_WID': '[um] Slit width',
#               'STEPSIZE': '[arcsec] Scanning step size',
#               'STEPANGL': '[degrees] Scanning step angle',
#               'SLITCNTR': 'slit center starting point',
#               'CHECKSUM': 'HDU checksum updated 2021-12-03T03:10:48',
#               'DATASUM': 'data unit checksum updated 2021-12-03T03:10:48',
#               'FF1WLOFF': '[Angstrom] WL-offset FF1',
#               'FF1WLDSP': '[Angstrom/pixel] WL-dispersion FF1',
#               'FF1FWHMA': '[Angstrom] spectral FWHM FF1',
#               'FF1FWHMP': '[pixel] spectral FWHM FF1',
#               'FF1STRAY': 'spectral straylight FF1',
#               'FF1NPOLY': 'order of fitted polynomial FF1',
#               'FF1PAR00': 'polynomial fit coefficient 00 FF1',
#               'FF1PAR01': 'polynomial fit coefficient 01 FF1',
#               'FF1PAR02': 'polynomial fit coefficient 02 FF1',
#               'FF1PAR03': 'polynomial fit coefficient 03 FF1',
#               'FF1PAR04': 'polynomial fit coefficient 04 FF1',
#               'FF1PAR05': 'polynomial fit coefficient 05 FF1',
#               'FF1PAR06': 'polynomial fit coefficient 06 FF1',
#               'FF1PAR07': 'polynomial fit coefficient 07 FF1',
#               'FF1PAR08': 'polynomial fit coefficient 08 FF1',
#               'FF1PAR09': 'polynomial fit coefficient 09 FF1',
#               'FF1PAR10': 'polynomial fit coefficient 10 FF1',
#               'FF1PAR11': 'polynomial fit coefficient 11 FF1',
#               'FF1PAR12': 'polynomial fit coefficient 12 FF1',
#               'FF1PAR13': 'polynomial fit coefficient 13 FF1',
#               'FF1PAR14': 'polynomial fit coefficient 14 FF1',
#               'FF1PAR15': 'polynomial fit coefficient 15 FF1',
#               'FF1PAR16': 'polynomial fit coefficient 16 FF1',
#               'FF1PAR17': 'polynomial fit coefficient 17 FF1',
#               'FF1PAR18': 'polynomial fit coefficient 18 FF1',
#               'FF1PAR19': 'polynomial fit coefficient 19 FF1',
#               'FF1PAR20': 'polynomial fit coefficient 20 FF1',
#               'FF1PAR21': 'polynomial fit coefficient 21 FF1',
#               'FF1PAR22': 'polynomial fit coefficient 22 FF1',
#               'FF1PAR23': 'polynomial fit coefficient 23 FF1',
#               'FF1PAR24': 'polynomial fit coefficient 24 FF1',
#               'FF1PAR25': 'polynomial fit coefficient 25 FF1',
#               'FF1PAR26': 'polynomial fit coefficient 26 FF1',
#               'FF1PAR27': 'polynomial fit coefficient 27 FF1',
#               'FF1PAR28': 'polynomial fit coefficient 28 FF1',
#               'FF2WLOFF': '[Angstrom] WL-offset',
#               'FF2WLDSP': '[Angstrom/pixel] WL-dispersion FF2',
#               'FF2FWHMA': '[Angstrom] spectral FWHM FF2',
#               'FF2FWHMP': '[pixel] spectral FWHM FF2',
#               'FF2STRAY': 'spectral straylight FF2',
#               'FF2NPOLY': 'order of fitted polynomial FF2',
#               'FF2PAR00': 'polynomial fit coefficient 00 FF2',
#               'FF2PAR01': 'polynomial fit coefficient 01 FF2',
#               'FF2PAR02': 'polynomial fit coefficient 02 FF2',
#               'FF2PAR03': 'polynomial fit coefficient 03 FF2',
#               'FF2PAR04': 'polynomial fit coefficient 04 FF2',
#               'FF2PAR05': 'polynomial fit coefficient 05 FF2',
#               'FF2PAR06': 'polynomial fit coefficient 06 FF2',
#               'FF2PAR07': 'polynomial fit coefficient 07 FF2',
#               'FF2PAR08': 'polynomial fit coefficient 08 FF2',
#               'FF2PAR09': 'polynomial fit coefficient 09 FF2',
#               'FF2PAR10': 'polynomial fit coefficient 10 FF2',
#               'FF2PAR11': 'polynomial fit coefficient 11 FF2',
#               'FF2PAR12': 'polynomial fit coefficient 12 FF2',
#               'FF2PAR13': 'polynomial fit coefficient 13 FF2',
#               'FF2PAR14': 'polynomial fit coefficient 14 FF2',
#               'FF2PAR15': 'polynomial fit coefficient 15 FF2',
#               'FF2PAR16': 'polynomial fit coefficient 16 FF2',
#               'FF2PAR17': 'polynomial fit coefficient 17 FF2',
#               'FF2PAR18': 'polynomial fit coefficient 18 FF2',
#               'FF2PAR19': 'polynomial fit coefficient 19 FF2',
#               'FF2PAR20': 'polynomial fit coefficient 20 FF2',
fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091604_l1p_003_001_0169.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091607_l1p_003_001_0170.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091610_l1p_003_001_0171.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091613_l1p_003_001_0172.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091616_l1p_003_001_0173.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091619_l1p_003_001_0174.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091622_l1p_003_001_0175.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091625_l1p_003_001_0176.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091628_l1p_003_001_0177.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091631_l1p_003_001_0178.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091634_l1p_003_001_0179.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091637_l1p_003_001_0180.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091640_l1p_003_001_0181.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091642_l1p_003_001_0182.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091645_l1p_003_001_0183.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091648_l1p_003_001_0184.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091651_l1p_003_001_0185.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091654_l1p_003_001_0186.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091657_l1p_003_001_0187.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091700_l1p_003_001_0188.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091703_l1p_003_001_0189.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091706_l1p_003_001_0190.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091709_l1p_003_001_0191.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091712_l1p_003_001_0192.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091715_l1p_003_001_0193.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091718_l1p_003_001_0194.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091721_l1p_003_001_0195.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091724_l1p_003_001_0196.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091727_l1p_003_001_0197.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091729_l1p_003_001_0198.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091732_l1p_003_001_0199.fits'),
#  PosixPath('/home/harsh/CourseworkRepo/KWS 2022/gris_20201120_003/l1_data/gris_20201120_091735_l1p_003_001_0200.fits')]

# %%
def get_spectral_image(scannumber, stokes):
    data, header = sunpy.io.fits.read(files[scannumber])[0]
    if stokes == 0:
        return data[stokes, :, :, 0].T / max_val
    else:
        return data[stokes, :, :, 0].T / data[0, :, :, 0].T

spatial_image = None
max_val = None

def get_spatial_image(wavelength_position):
    global spatial_image, max_val
    if spatial_image is not None:
        return spatial_image[wavelength_position]
    data, header = sunpy.io.fits.read(files[0])[0]
    spatial_image = np.zeros((data.shape[1], len(files), data.shape[2]), dtype=np.float64)
    for i in range(len(files)):
        data, header = sunpy.io.fits.read(files[i])[0]
        spatial_image[:, i] = data[0, :, :, 0]
    if max_val is None:
        max_val = spatial_image.max()
    return spatial_image[wavelength_position]

def get_stokes_params(scannumber, slitposition):
    data, header = sunpy.io.fits.read(files[scannumber])[0]
    return data[:, :, slitposition, 0] / max_val

# %%
plt.imshow(get_spatial_image(500), cmap='gray', origin='lower')

# %%
plt.imshow(get_spectral_image(199, 3), cmap='gray', origin='lower')

# %%
size = plt.rcParams['lines.markersize']
wave = np.arange(15640.899, 15640.899 + (1010 * 0.039917), 0.039917)[:-1]
scannumber = 92
slitposition = 301
waveposition = 0
stokesposition = 0

fig, axs = plt.subplots(3, 2, figsize=(10 * 1920/1080, 10))
im01a = axs[0][1].imshow(get_spatial_image(waveposition), cmap='gray', origin='lower')
im00 = axs[0][0].imshow(get_spectral_image(scannumber, stokesposition), cmap='gray', origin='lower')

iquv = get_stokes_params(scannumber, slitposition).astype(np.float64)
for i in range(1, 4):
    iquv[i] = np.round(iquv[i] * 100 / iquv[0], 2)
print (wave.shape, iquv.shape)
im10, = axs[1][0].plot(wave, iquv[0])
im10b = axs[1][0].axvline(wave[waveposition], linestyle='--', color='black', linewidth=0.5)
im11, = axs[1][1].plot(wave, iquv[1])
im20, = axs[2][0].plot(wave, iquv[2])
im21, = axs[2][1].plot(wave, iquv[3])

# axs[1][0].set_ylim(0.35, 0.8)
axs[1][0].set_ylim(np.abs(iquv[0]).min() * 0.95, np.abs(iquv[0]).max() * 1.05)
axs[1][1].set_ylim(-np.abs(iquv[1]).max() * 1.05, np.abs(iquv[1]).max() * 1.05)
axs[2][0].set_ylim(-np.abs(iquv[2]).max() * 1.05, np.abs(iquv[2]).max() * 1.05)
axs[2][1].set_ylim(-np.abs(iquv[3]).max() * 1.05, np.abs(iquv[3]).max() * 1.05)

xx = [slit_position]
yy = [scannumber]

im01b = axs[0][1].scatter(slitposition, scannumber, marker='+', color='red', linewidths=1, s=(size**2) * 8)
im01c, = axs[0][1].plot(np.ones(440) * scannumber, linestyle='--', color='black', linewidth='0.5')

axs[0][0].text(
    -0.22,
    0.5,
    'Stokes',
    transform=axs[0][0].transAxes,
    rotation=90
)

xtick_pos = np.array([15640, 15645, 15650, 15655, 15660, 15665, 15670, 15675, 15680])
axs[0][0].set_xticks((xtick_pos[1:] - 15640.899) / 0.039917, xtick_pos[1:])
axs[0][0].set_yticks(np.array([0, 10, 20, 30, 40, 50])/0.135, [0, 10, 20, 30, 40, 50])
axs[0][1].set_xticks(np.array([0, 10, 20, 30, 40, 50])/0.135, [0, 10, 20, 30, 40, 50])
axs[0][1].set_yticks(np.array([0, 10, 20])/0.135, [0, 10, 20])

axs[0][0].yaxis.set_minor_locator(MultipleLocator(1/0.135))

axs[0][1].xaxis.set_minor_locator(MultipleLocator(1/0.135))
axs[0][1].yaxis.set_minor_locator(MultipleLocator(1/0.135))

axs[1][0].xaxis.set_minor_locator(MultipleLocator(0.5))
axs[1][1].xaxis.set_minor_locator(MultipleLocator(0.5))
axs[2][0].xaxis.set_minor_locator(MultipleLocator(0.5))
axs[2][1].xaxis.set_minor_locator(MultipleLocator(0.5))

axs[0][0].set_ylabel(r'x [arcsec]')
axs[0][1].set_xlabel(r'x [arcsec]')
axs[0][1].set_ylabel(r'y [arcsec]')
axs[1][0].set_ylabel(r'$I/I_{c}$')
axs[1][1].set_ylabel(r'$Q/I$ [%]')
axs[2][0].set_ylabel(r'$U/I$ [%]')
axs[2][1].set_ylabel(r'$V/I$ [%]')
axs[2][0].set_xlabel(r'Wavelength [$\mathrm{\AA}$]')
axs[2][1].set_xlabel(r'Wavelength [$\mathrm{\AA}$]')

stokes_axs = plt.axes([0.03, 0.685, 0.03, 0.25])
scan_axs = plt.axes([0.13, 0.96, 0.3, 0.03])
wave_axs = plt.axes([0.6, 0.96, 0.25, 0.03])

def update_stokes(val):
    global scannumber, stokesposition
    stokesposition = val
    dd = get_spectral_image(scannumber, stokesposition)
    im00.set_data(dd)
    im00.set_clim(dd.min(), dd.max())
    fig.canvas.draw_idle()

def update_scan(val):
    global scannumber, stokesposition
    scannumber = val
    dd = get_spectral_image(scannumber, stokesposition)
    im00.set_data(dd)
    im00.set_clim(dd.min(), dd.max())
    im01c.set_ydata(np.ones(440) * scannumber)
    fig.canvas.draw_idle()

def update_wave(val):
    global waveposition
    waveposition = np.argmin(np.abs(wave - val))
    dd = get_spatial_image(waveposition)
    im01a.set_data(dd)
    im01a.set_clim(dd.min(), dd.max())
    im10b.set_xdata(wave[waveposition])
    fig.canvas.draw_idle()

def on_click_event(event):
    global scannumber, slitposition, xx, yy
    ax = event.inaxes

    if ax is None or ax != axs[0][1]:
        return
    
    slitposition = np.round(event.xdata, 0).astype(np.int64)
    scannumber = np.round(event.ydata, 0).astype(np.int64)

    iquv = get_stokes_params(scannumber, slitposition).astype(np.float64)
    for i in range(1, 4):
        iquv[i] = np.round(iquv[i] * 100 / iquv[0], 2)

    im10.set_ydata(iquv[0])
    im11.set_ydata(iquv[1])
    im20.set_ydata(iquv[2])
    im21.set_ydata(iquv[3])
    
    axs[1][0].set_ylim(np.abs(iquv[0]).min() * 0.95, np.abs(iquv[0]).max() * 1.05)
    axs[1][1].set_ylim(-np.abs(iquv[1]).max() * 1.05, np.abs(iquv[1]).max() * 1.05)
    axs[2][0].set_ylim(-np.abs(iquv[2]).max() * 1.05, np.abs(iquv[2]).max() * 1.05)
    axs[2][1].set_ylim(-np.abs(iquv[3]).max() * 1.05, np.abs(iquv[3]).max() * 1.05)
    
    xx = [slitposition]
    yy = [scannumber]
    im01b.set_offsets(np.c_[xx,yy])

    fig.canvas.draw_idle()

stokes_slider = Slider(
    ax=stokes_axs,
    label='',
    valmin=0,
    valmax=3,
    valinit=0,
    valstep=1,
    orientation='vertical'
)
scan_slider = Slider(
    ax=scan_axs,
    label='',
    valmin=0,
    valmax=199,
    valinit=scannumber,
    valstep=1
)
wave_slider = Slider(
    ax=wave_axs,
    label='',
    valmin=15640.899,
    valmax=15681.175253,
    valinit=15640.899,
    valstep=0.039917
)
stokes_slider.on_changed(update_stokes)
scan_slider.on_changed(update_scan)
wave_slider.on_changed(update_wave)
fig.canvas.mpl_connect('button_press_event', on_click_event)

plt.subplots_adjust(left=0.1, bottom=0.05, right=0.99, top=0.95, wspace=0.2, hspace=0.2)
plt.show()
# Out:
# (1010,) (4, 1010)

# %%
np.arange(100, 103, 1)
# Out:
# array([100, 101, 102])

# %%
wave = np.arange(15640.899, 15640.899 + (1010 * 0.039917), 0.039917)

# %%
wave = np.arange(15640.899, 15640.899 + (1010 * 0.039917), 0.039917)

# %%
wave.shape
# Out:
# (1011,)

# %%
wave
# Out:
# array([15640.899   , 15640.938917, 15640.978834, ..., 15681.135336,
#        15681.175253, 15681.21517 ])

# %%
np.arange(15640, 15640+45, 5)
# Out:
# array([15640, 15645, 15650, 15655, 15660, 15665, 15670, 15675, 15680])

# %%
(xtick_pos - 15640.899) / 0.039917
# Out:
# array([-22.5217326 , 102.73818173, 227.99809605, 353.25801037,
#        478.51792469, 603.77783902, 729.03775334, 854.29766766,
#        979.55758198])

# %%
splitting = 15648.459-15648.066

# %%
mag_field = splitting / (4.67e-13 * 15648.514**2)

# %%
mag_field
# Out:
# 3436.603786618302
